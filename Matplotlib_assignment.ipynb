# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1
# **Note:**Please write your analysis after every plot in your own words what you observe from the plot
# 1.   Load your company_sales_data.csv CSV file
# 2.   Read Total profit of all months and show it using a line plot
# 3.   Generated line plot must include following Style properties: –
#
# Line Style dotted and Line-color should be red<br>
# Show legend at the lower right location.<br>
# X label name = Month Number<br>
# Y label name = Sold units number<br>
# Add a circle marker.<br>
# Line marker color as read<br>
# Line width should be 3
#
# Your graph should look like this:
#
# ![image.png](data:image/png;base64,...)

# %%
# TASK 1.1
sales = pd.read_csv('company_sales_data.csv')
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
# TASK 1.2

x = sales.total_profit

plt.plot(x)

plt.show()

# %%
# TASK 1.3

x = sales.month_number
y = sales.total_units

plt.plot(x,y,'ro', x,y,'r--', marker = 'o', mec= 'r', linewidth=3, linestyle='dashed', markerfacecolor='k')

plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.title('company sales data of last year')

plt.legend(['Profit data of last year'],loc='lower right')

plt.show()

# %% [markdown]
# 4.  Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).<br>
#
# ![image.png](data:image/png;base64,...)

# %%
# TASK 1.4

plt.figure(figsize=(12,6))

x  = sales.month_number
y1 = sales.facecream
y2 = sales.facewash
y3 = sales.toothpaste
y4 = sales.bathingsoap
y5 = sales.shampoo
y6 = sales.moisturizer

plt.plot(x, y1, label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(x, y2, label = 'Face wash Sales Data', marker='o', linewidth=3)
plt.plot(x, y3, label = 'Tooth paste Sales Data', marker='o', linewidth=3)
plt.plot(x, y4, label = 'Bathing soap Sales Data', marker='o', linewidth=3)
plt.plot(x, y5, label = 'Shampoo Sales Data', marker='o', linewidth=3)
plt.plot(x, y6, label = 'Moisturizer Sales Data', marker='o', linewidth=3)


plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(x)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %% [markdown]
# # Task 2
# 5. Read toothpaste sales data of each month and show it using a scatter plot<br>
# Also, add a grid in the plot
#
# 6.   Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
# 7.  Calculate total sale data for last year for each product and show it using a Pie chart.your pie chart output should like this.
#
# ![image.png](data:image/png;base64,...)

# %%
# TASK 2.5

plt.figure(figsize=(12,6))

x  = sales.month_number
y3 = sales.toothpaste

plt.scatter(x, y3,label = 'tooth paste sales data')

plt.xlabel('Month Number')
plt.ylabel('Sales units in number for tooth paste')
plt.legend(loc='upper left')
plt.xticks(x)
#plt.yticks(y3)
plt.title('Sales data')
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %%
# TASK 2.6

plt.figure(figsize=(12,6))

x  = sales.month_number
y4 = sales.bathingsoap

plt.bar(x, y4,label = 'bathing soap sales data')

plt.xlabel('Month Number')
plt.ylabel('Sales units in number for bathing soap')
plt.legend(loc='upper left')
plt.xticks(x)
#plt.yticks(y3)
plt.title('Sales data')
plt.grid(True, linewidth= 1, linestyle="--")
plt.savefig('/Users/pranayvaddepalli/Desktop/Python/Matplotlib_assignment/sales_data_of_bathingsoap.png', dpi=150)
plt.show()

# %%
# TASK 2.7

plt.figure(figsize=(12,8))

x  = sales.month_number

y1 = sales.facecream.sum()
y2 = sales.facewash.sum()
y3 = sales.toothpaste.sum()
y4 = sales.bathingsoap.sum()
y5 = sales.shampoo.sum()
y6 = sales.moisturizer.sum()

data = [y1, y2, y3, y4, y5, y6]

labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']

plt.axis("equal")

plt.pie(data, labels=labels, autopct="%1.1f%%")

plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# 8.  Read Bathing soap ,facewash of all months and display it using
# the Subplot.your output should be like this as mention below:
# ![image.png](data:image/png;base64,...)
#
# 9.Read all product sales data and show it using the stack plot
#   ![image.png](data:image/png;base64,...)

# %%
# TASK 2.8

plt.figure(figsize=(12,6))

x  = sales.month_number
y2 = sales.facewash
y4 = sales.bathingsoap

plt.subplot(2,1,1)
plt.plot(x, y4, label = 'Bathing soap Sales Data', marker='o', color='k', linewidth=3)
plt.title('Sales data of bathing soap')

plt.subplot(2,1,2)
plt.plot(x, y2, label = 'Face wash Sales Data', marker='o', color='r', linewidth=3)
plt.title('Sales data of face wash')

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.xticks(x)
#plt.yticks([1500, 2000, 7500, 10000, 12500, 15000])
plt.show()

# %%
# TASK 2.9

plt.figure(figsize=(12,8))

x  = sales.month_number
y1 = sales.facecream
y2 = sales.facewash
y3 = sales.toothpaste
y4 = sales.bathingsoap
y5 = sales.shampoo
y6 = sales.moisturizer

plt.plot([], [], label = 'Face cream', color='m', linewidth=3)
plt.plot([], [], label = 'Face wash', color='c', linewidth=3)
plt.plot([], [], label = 'Tooth paste', color='r', linewidth=3)
plt.plot([], [], label = 'Bathing soap', color='k', linewidth=3)
plt.plot([], [], label = 'Shampoo', color='g', linewidth=3)
plt.plot([], [], label = 'Moisturizer', color='y', linewidth=3)

plt.stackplot(x, y1, y2, y3, y4, y5, y6, colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title('All products sales data using stock plat')
plt.show()
